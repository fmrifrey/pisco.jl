# %% [markdown]
# # 3D PISCO sensitivity map estimation demo
# This notebook demonstrates how to use the `pisco_smaps` function to estimate sensitivity for 3D multichannel MRI data.

# %%
# load packages
using MIRTjim
using Plots
using FFTW
using Random
using LinearAlgebra
using MAT
using LinearMapsAA

# load helper functions
include("pisco.jl");
include("utils.jl");

# %%
# read in data from mat file
kdata = matread("./data/3D_GRE_data.mat")["kData"];
N = size(kdata)[1:3]; # image dimensions
Q = size(kdata, 4); # number of coils

# correct for the z-offset in the data (only for this dataset)
nslices = N[3]
dz = -22 # slice offset
kdata .*= reshape(exp.(1im * 2π * dz * collect(center_idcs(0, nslices)...) / nslices), (1, 1, nslices, 1)); # apply linear phase

# get image space data
idata = iftnd(kdata; dims=1:3);

# show the rms coil-combined image
idata_rms = sqrt.(sum(abs2.(idata); dims=4));
jim(idata_rms, title="RMS coil-combined image", colorbar=false)

# %%
# show channel-wise images of the center slice
jim(idata[:,:,round(Int,nslices/2),:], title="channel-wise images of center slice")

# %%
# set PISCO techniques
kernel_shape = 1; # (0 for rect, 1 for circle)
fft_C_mtx = 1; # option to approximate ChC with FFTs
sketched_SVD = 1; # option to used sketched (randomized) SVD
subspace_itr_G = 0; # option to use subspace iteration to compute nullspace vectors of G

# set PISCO parameters
τ = Int(3); # neighborhood size (radius)
N_cal = 32; # size of calibration region
σ_thresh = 0.002; # threshold for singular values
d_sk = 50; # sketch dimension for SVD of ChC (overestimation of the rank)
N_gzp = 24; # number of vo/pixels to interpolate (zero-pad) in each dimension of G matrix
α = 100; # Gaussian window parameter for phase normalization
L = 1; # number of sensitivity map sets to estimate

# %%
# estimate the sensitivity maps by calling the pisco_smaps function
smaps, λ = pisco_smaps(kdata;
    kernel_shape=kernel_shape,
    fft_C_mtx=fft_C_mtx,
    sketched_SVD=sketched_SVD,
    subspace_itr_G=subspace_itr_G,
    σ_thresh=σ_thresh,
    d_sk=d_sk,
    N_gzp=N_gzp,
    α=α,
    L=L,
    verbose=1);
# Out:
# PISCO parameters:
# 	kernel shape: circular
# 	kernel radius (τ): 3
# Task (runnable) @0x000000037b91c650

# %%
# show the estimated sensitivity maps at the center slice
jim(smaps[:,:,round(Int,nslices/2),:], title="Estimated SENSE maps at center slice")

# %%
# create sensitivity encoding operator
S = LinearMapAA(
    x -> x .* smaps, # forward
    y -> sum(conj.(smaps) .* y, dims=4), # adjoint
    (prod(N) * Q, prod(N)); # operator size
    T=ComplexF64, # data type
    idim=N, # input dimensions
    odim=(N..., Q) # output dimensions
);

# solve for coil-combined image using conjugate gradient
idata_coil_combined = cg(S, zeros(ComplexF64, N...), idata; niter=30);

# get representation error (NPR)
@show npr = norm(idata[:] - (S * idata_coil_combined)[:]) / norm(idata[:]);
# Out:
# UndefVarError: `smaps` not defined
#
#
#
# Stacktrace:
#
#   [1] (::var"#55#57")(x::Base.ReshapedArray{ComplexF64, 3, SubArray{ComplexF64, 1, Matrix{ComplexF64}, Tuple{Base.Slice{Base.OneTo{Int64}}, Int64}, true}, Tuple{}})
#
#     @ Main ~/code/pisco.jl/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X10sZmlsZQ==.jl:3
#
#   [2] (::LinearMapsAA.var"#6#10"{Tuple{Int64, Int64, Int64}, NTuple{4, Int64}, var"#55#57"})(x::SubArray{ComplexF64, 1, Matrix{ComplexF64}, Tuple{Base.Slice{Base.OneTo{Int64}}, Int64}, true})
#
#     @ LinearMapsAA ~/.julia/packages/LinearMapsAA/P0GrF/src/types.jl:141
#
#   [3] _unsafe_mul!(y::SubArray{ComplexF64, 1, Matrix{ComplexF64}, Tuple{Base.Slice{Base.OneTo{Int64}}, Int64}, true}, A::LinearMaps.FunctionMap{ComplexF64, LinearMapsAA.var"#6#10"{Tuple{Int64, Int64, Int64}, NTuple{4, Int64}, var"#55#57"}, LinearMapsAA.var"#8#12"{Tuple{Int64, Int64, Int64}, NTuple{4, Int64}, var"#56#58"}, false}, x::SubArray{ComplexF64, 1, Matrix{ComplexF64}, Tuple{Base.Slice{Base.OneTo{Int64}}, Int64}, true})
#
#     @ LinearMaps ~/.julia/packages/LinearMaps/GRDXH/src/functionmap.jl:127
#
#   [4] mul!
#
#     @ ~/.julia/packages/LinearMaps/GRDXH/src/LinearMaps.jl:166 [inlined]
#
#   [5] _generic_map_mul!(y::SubArray{ComplexF64, 1, Matrix{ComplexF64}, Tuple{Base.Slice{Base.OneTo{Int64}}, Int64}, true}, A::LinearMaps.FunctionMap{ComplexF64, LinearMapsAA.var"#6#10"{Tuple{Int64, Int64, Int64}, NTuple{4, Int64}, var"#55#57"}, LinearMapsAA.var"#8#12"{Tuple{Int64, Int64, Int64}, NTuple{4, Int64}, var"#56#58"}, false}, x::SubArray{ComplexF64, 1, Matrix{ComplexF64}, Tuple{Base.Slice{Base.OneTo{Int64}}, Int64}, true}, α::Int64, β::Int64)
#
#     @ LinearMaps ~/.julia/packages/LinearMaps/GRDXH/src/LinearMaps.jl:274
#
#   [6] _unsafe_mul!
#
#     @ ~/.julia/packages/LinearMaps/GRDXH/src/LinearMaps.jl:265 [inlined]
#
#   [7] mul!
#
#     @ ~/.julia/packages/LinearMaps/GRDXH/src/LinearMaps.jl:230 [inlined]
#
#   [8] lm_mul!
#
#     @ ~/.julia/packages/LinearMapsAA/P0GrF/src/multiply.jl:87 [inlined]
#
#   [9] lmao_mul!(Y::Array{ComplexF64, 4}, Lm::LinearMaps.FunctionMap{ComplexF64, LinearMapsAA.var"#6#10"{Tuple{Int64, Int64, Int64}, NTuple{4, Int64}, var"#55#57"}, LinearMapsAA.var"#8#12"{Tuple{Int64, Int64, Int64}, NTuple{4, Int64}, var"#56#58"}, false}, X::Array{ComplexF64, 3}, α::Int64, β::Int64; idim::Tuple{Int64, Int64, Int64}, odim::NTuple{4, Int64})
#
#     @ LinearMapsAA ~/.julia/packages/LinearMapsAA/P0GrF/src/multiply.jl:153
#
#  [10] lmax_mul(A::LinearMapAO{ComplexF64, 4, 3, LinearMaps.FunctionMap{ComplexF64, LinearMapsAA.var"#6#10"{Tuple{Int64, Int64, Int64}, NTuple{4, Int64}, var"#55#57"}, LinearMapsAA.var"#8#12"{Tuple{Int64, Int64, Int64}, NTuple{4, Int64}, var"#56#58"}, false}, @NamedTuple{}}, X::Array{ComplexF64, 3})
#
#     @ LinearMapsAA ~/.julia/packages/LinearMapsAA/P0GrF/src/multiply.jl:212
#
#  [11] *
#
#     @ ~/.julia/packages/LinearMapsAA/P0GrF/src/multiply.jl:191 [inlined]
#
#  [12] cg(A::LinearMapAO{ComplexF64, 4, 3, LinearMaps.FunctionMap{ComplexF64, LinearMapsAA.var"#6#10"{Tuple{Int64, Int64, Int64}, NTuple{4, Int64}, var"#55#57"}, LinearMapsAA.var"#8#12"{Tuple{Int64, Int64, Int64}, NTuple{4, Int64}, var"#56#58"}, false}, @NamedTuple{}}, x0::Array{ComplexF64, 3}, b::Array{ComplexF64, 4}; niter::Int64, tol::Float64)
#
#     @ Main ~/code/pisco.jl/utils.jl:77
#
#  [13] top-level scope
#
#     @ ~/code/pisco.jl/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X10sZmlsZQ==.jl:9

# %%
# show the coil-combined image
jim(idata_coil_combined, title="Coil-combined image (PISCO)", colorbar=false)
# Out:
# UndefVarError: `idata_coil_combined` not defined
#
#
#
# Stacktrace:
#
#  [1] top-level scope
#
#    @ ~/code/pisco.jl/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_X11sZmlsZQ==.jl:2
